# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %%
rick = pd.read_csv('asset-v1_IRONHACK+DAFT+202002_SAO+type@asset+block@rick_diamonds.csv')

# %%
rick.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z
# 0   0.91  Very Good     H     SI2   63.4   57.0  6.10  6.18  3.89
# 1   0.38       Good     F     VS2   60.3   61.0  4.68  4.71  2.83
# 2   0.52      Ideal     H     VS2   61.8   56.0  5.19  5.16  3.20
# 3   1.10      Ideal     G     VS1   61.3   56.0  6.65  6.69  4.09
# 4   2.28      Ideal     G     SI2   61.6   57.0  8.44  8.37  5.18

# %%
rick['cut'].unique()
# Out:
# array(['Very Good', 'Good', 'Ideal', 'Premium', 'Fair'], dtype=object)

# %%
rick['color'].unique()
# Out:
# array(['H', 'F', 'G', 'J', 'E', 'I', 'D'], dtype=object)

# %%
rick['clarity'].unique()
# Out:
# array(['SI2', 'VS2', 'VS1', 'SI1', 'IF', 'VVS2', 'I1', 'VVS1'],
#       dtype=object)

# %%
rick.describe()
# Out:
#              carat        depth        table            x            y  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      0.799144    61.724680    57.516140     5.735516     5.736410
# std       0.472936     1.457691     2.244019     1.120300     1.110345
# min       0.200000    44.000000    50.000000     0.000000     0.000000
# 25%       0.400000    61.000000    56.000000     4.720000     4.720000
# 50%       0.710000    61.800000    57.000000     5.710000     5.720000
# 75%       1.040000    62.500000    59.000000     6.530000     6.520000
# max       4.130000    73.600000    70.000000    10.000000     9.850000
#
#                  z
# count  5000.000000
# mean      3.539576
# std       0.694733
# min       0.000000
# 25%       2.910000
# 50%       3.530000
# 75%       4.032500
# max       6.430000

# %%
cut_01 = rick[(rick['cut']=='Ideal') | (rick['cut']=='Premium')]
cut_02 = rick[(rick['cut']=='Very Good') | (rick['cut']=='Good')]
cut_03 = rick[(rick['cut']=='Fair')]

# %%
def cat_cut(x):
    """
    Function to categorize the types of diamond cut
    
    """
    if ((x.upper() == 'IDEAL') | ( x.upper() =='PREMIUM')):
        return '1'
    elif ((x.upper() == 'VERY GOOD') | ( x.upper() =='GOOD')):
        return '2'
    elif ((x.upper() == 'FAIR')):
        return '3'

# %%
rick['cut_group'] = rick['cut'].apply(cat_cut)

# %%
colors_01 = rick[(rick['color']=='D') | (rick['color']=='E') | (rick['color']=='F')]
colors_02 = rick[(rick['color']=='G') | (rick['color']=='H') | (rick['color']=='I') | (rick['color']=='J')]
colors_03 = rick[(rick['color']=='K') | (rick['color']=='L') | (rick['color']=='M')]
colors_04 = rick[(rick['color']=='N') | (rick['color']=='O') | (rick['color']=='P') | (rick['color']=='Q') | (rick['color']=='R')]
colors_05 = rick[(rick['color']=='S') | (rick['color']=='T') | (rick['color']=='U') | (rick['color']=='V') | (rick['color']=='X') | (rick['color']=='Y') | (rick['color']=='Z')]

# %%
def cat_color(x):
    """
    Function to categorize the types of diamond color
    
    """
    if ((x.upper() == 'D') | ( x.upper() =='E') | ( x.upper() =='F')):
        return '1'
    elif ((x.upper() == 'G') | ( x.upper() =='H') | ( x.upper() =='I') | ( x.upper() =='J')):
        return '2'
    elif ((x.upper() == 'K') | (x.upper() == 'L') | ( x.upper() =='M')):
        return '3'
    elif ((x.upper() == 'N') | (x.upper() == 'O') | (x.upper() == 'P') | ( x.upper() =='Q') | ( x.upper() =='R')):
        return '4'
    elif ((x.upper() == 'S') | (x.upper() == 'T') | (x.upper() == 'U') | ( x.upper() =='V') | ( x.upper() =='X') | ( x.upper() =='Y') | ( x.upper() =='Z')):
        return '5'

# %%
rick['color_group'] = rick['color'].apply(cat_color)

# %%
clarity_01 = rick[(rick['clarity'] == 'IF')]
clarity_02 = rick[(rick['clarity'] == 'VVS1') | (rick['clarity'] == 'VVS2')]
clarity_03 = rick[(rick['clarity'] == 'VS1') | (rick['clarity'] == 'VS2')]
clarity_04 = rick[(rick['clarity'] == 'SI1') | (rick['clarity'] == 'SI2')]
clarity_05 = rick[(rick['clarity'] == 'I1')]

# %%
def cat_clarity(x):
    """
    Function to categorize the types of diamond clarity
    
    """
    if x.upper() == 'IF':
        return '1'
    elif ((x.upper() == 'VVS1') | ( x.upper() =='VVS2')):
        return '2'
    elif ((x.upper() == 'VS1') | (x.upper() == 'VS2')):
        return '3'
    elif ((x.upper() == 'SI1') | (x.upper() == 'SI2') | (x.upper() == 'SI3')):
        return '4'
    elif ((x.upper() == 'I1') | (x.upper() == 'I2') | (x.upper() == 'I3')):
        return '5'

# %%
rick['clarity_group'] = rick['clarity'].apply(cat_clarity)

# %%
rick.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z cut_group  \
# 0   0.91  Very Good     H     SI2   63.4   57.0  6.10  6.18  3.89         2
# 1   0.38       Good     F     VS2   60.3   61.0  4.68  4.71  2.83         2
# 2   0.52      Ideal     H     VS2   61.8   56.0  5.19  5.16  3.20         1
# 3   1.10      Ideal     G     VS1   61.3   56.0  6.65  6.69  4.09         1
# 4   2.28      Ideal     G     SI2   61.6   57.0  8.44  8.37  5.18         1
#
#   color_group clarity_group
# 0           2             4
# 1           1             3
# 2           2             3
# 3           2             3
# 4           2             4

# %%
diamond = pd.read_csv('asset-v1_IRONHACK+DAFT+202002_SAO+type@asset+block@diamonds.csv')

# %%
cut_01 = diamond[(diamond['cut']=='Ideal') | (diamond['cut']=='Premium')]
cut_02 = diamond[(diamond['cut']=='Very Good') | (diamond['cut']=='Good')]
cut_03 = diamond[(diamond['cut']=='Fair')]

# %%
def cat_cut(x):
    """
    Function to categorize the types of diamond cut
    
    """
    if ((x.upper() == 'IDEAL') | ( x.upper() =='PREMIUM')):
        return '1'
    elif ((x.upper() == 'VERY GOOD') | ( x.upper() =='GOOD')):
        return '2'
    elif ((x.upper() == 'FAIR')):
        return '3'

# %%
diamond['cut_group'] = diamond['cut'].apply(cat_cut)

# %%
colors_01 = diamond[(diamond['color']=='D') | (diamond['color']=='E') | (diamond['color']=='F')]
colors_02 = diamond[(diamond['color']=='G') | (diamond['color']=='H') | (diamond['color']=='I') | (diamond['color']=='J')]
colors_03 = diamond[(diamond['color']=='K') | (diamond['color']=='L') | (diamond['color']=='M')]
colors_04 = diamond[(diamond['color']=='N') | (diamond['color']=='O') | (diamond['color']=='P') | (diamond['color']=='Q') | (diamond['color']=='R')]
colors_05 = diamond[(diamond['color']=='S') | (diamond['color']=='T') | (diamond['color']=='U') | (diamond['color']=='V') | (diamond['color']=='X') | (diamond['color']=='Y') | (diamond['color']=='Z')]

# %%
def cat_color(x):
    """
    Function to categorize the types of diamond color
    
    """
    if ((x.upper() == 'D') | ( x.upper() =='E') | ( x.upper() =='F')):
        return '1'
    elif ((x.upper() == 'G') | ( x.upper() =='H') | ( x.upper() =='I') | ( x.upper() =='J')):
        return '2'
    elif ((x.upper() == 'K') | (x.upper() == 'L') | ( x.upper() =='M')):
        return '3'
    elif ((x.upper() == 'N') | (x.upper() == 'O') | (x.upper() == 'P') | ( x.upper() =='Q') | ( x.upper() =='R')):
        return '4'
    elif ((x.upper() == 'S') | (x.upper() == 'T') | (x.upper() == 'U') | ( x.upper() =='V') | ( x.upper() =='X') | ( x.upper() =='Y') | ( x.upper() =='Z')):
        return '5'

# %%
diamond['color_group'] = diamond['color'].apply(cat_color)

# %%
clarity_01 = diamond[(diamond['clarity'] == 'IF')]
clarity_02 = diamond[(diamond['clarity'] == 'VVS1') | (diamond['clarity'] == 'VVS2')]
clarity_03 = diamond[(diamond['clarity'] == 'VS1') | (diamond['clarity'] == 'VS2')]
clarity_04 = diamond[(diamond['clarity'] == 'SI1') | (diamond['clarity'] == 'SI2')]
clarity_05 = diamond[(diamond['clarity'] == 'I1')]

# %%
def cat_clarity(x):
    """
    Function to categorize the types of diamond clarity
    
    """
    if x.upper() == 'IF':
        return '1'
    elif ((x.upper() == 'VVS1') | ( x.upper() =='VVS2')):
        return '2'
    elif ((x.upper() == 'VS1') | (x.upper() == 'VS2')):
        return '3'
    elif ((x.upper() == 'SI1') | (x.upper() == 'SI2') | (x.upper() == 'SI3')):
        return '4'
    elif ((x.upper() == 'I1') | (x.upper() == 'I2') | (x.upper() == 'I3')):
        return '5'

# %%
diamond['clarity_group'] = diamond['clarity'].apply(cat_clarity)

# %%
diamond.head()
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z  \
# 0   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 1   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 2   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 3   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 4   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
#
#   cut_group color_group clarity_group
# 0         1           1             4
# 1         2           1             3
# 2         1           2             3
# 3         2           2             4
# 4         2           2             2

# %%
clarity_color_cut_01 = diamond[(diamond['clarity_group']== '1') & (diamond['color_group']== '1') & (diamond['cut_group']== '1')]
clarity_color_cut_02 = diamond[(diamond['clarity_group']== '1') & (diamond['color_group']== '1') & (diamond['cut_group']== '2')]
clarity_color_cut_03 = diamond[(diamond['clarity_group']== '1') & (diamond['color_group']== '1') & (diamond['cut_group']== '3')]
clarity_color_cut_04 = diamond[(diamond['clarity_group']== '1') & (diamond['color_group']== '2') & (diamond['cut_group']== '1')]
clarity_color_cut_05 = diamond[(diamond['clarity_group']== '1') & (diamond['color_group']== '2') & (diamond['cut_group']== '2')]
clarity_color_cut_06 = diamond[(diamond['clarity_group']== '1') & (diamond['color_group']== '2') & (diamond['cut_group']== '3')]
clarity_color_cut_07 = diamond[(diamond['clarity_group']== '2') & (diamond['color_group']== '1') & (diamond['cut_group']== '1')]
clarity_color_cut_08 = diamond[(diamond['clarity_group']== '2') & (diamond['color_group']== '1') & (diamond['cut_group']== '2')]
clarity_color_cut_09 = diamond[(diamond['clarity_group']== '2') & (diamond['color_group']== '1') & (diamond['cut_group']== '3')]
clarity_color_cut_10 = diamond[(diamond['clarity_group']== '2') & (diamond['color_group']== '2') & (diamond['cut_group']== '1')]
clarity_color_cut_11 = diamond[(diamond['clarity_group']== '2') & (diamond['color_group']== '2') & (diamond['cut_group']== '2')]
clarity_color_cut_12 = diamond[(diamond['clarity_group']== '2') & (diamond['color_group']== '2') & (diamond['cut_group']== '3')]
clarity_color_cut_13 = diamond[(diamond['clarity_group']== '3') & (diamond['color_group']== '1') & (diamond['cut_group']== '1')]
clarity_color_cut_14 = diamond[(diamond['clarity_group']== '3') & (diamond['color_group']== '1') & (diamond['cut_group']== '2')]
clarity_color_cut_15 = diamond[(diamond['clarity_group']== '3') & (diamond['color_group']== '1') & (diamond['cut_group']== '3')]
clarity_color_cut_16 = diamond[(diamond['clarity_group']== '3') & (diamond['color_group']== '2') & (diamond['cut_group']== '1')]
clarity_color_cut_17 = diamond[(diamond['clarity_group']== '3') & (diamond['color_group']== '2') & (diamond['cut_group']== '2')]
clarity_color_cut_18 = diamond[(diamond['clarity_group']== '3') & (diamond['color_group']== '2') & (diamond['cut_group']== '3')]
clarity_color_cut_19 = diamond[(diamond['clarity_group']== '4') & (diamond['color_group']== '1') & (diamond['cut_group']== '1')]
clarity_color_cut_20 = diamond[(diamond['clarity_group']== '4') & (diamond['color_group']== '1') & (diamond['cut_group']== '2')]
clarity_color_cut_21 = diamond[(diamond['clarity_group']== '4') & (diamond['color_group']== '1') & (diamond['cut_group']== '3')]
clarity_color_cut_22 = diamond[(diamond['clarity_group']== '4') & (diamond['color_group']== '2') & (diamond['cut_group']== '1')]
clarity_color_cut_23 = diamond[(diamond['clarity_group']== '4') & (diamond['color_group']== '2') & (diamond['cut_group']== '2')]
clarity_color_cut_24 = diamond[(diamond['clarity_group']== '4') & (diamond['color_group']== '2') & (diamond['cut_group']== '3')]
clarity_color_cut_25 = diamond[(diamond['clarity_group']== '5') & (diamond['color_group']== '1') & (diamond['cut_group']== '1')]
clarity_color_cut_26 = diamond[(diamond['clarity_group']== '5') & (diamond['color_group']== '1') & (diamond['cut_group']== '2')]
clarity_color_cut_27 = diamond[(diamond['clarity_group']== '5') & (diamond['color_group']== '1') & (diamond['cut_group']== '3')]
clarity_color_cut_28 = diamond[(diamond['clarity_group']== '5') & (diamond['color_group']== '2') & (diamond['cut_group']== '1')]
clarity_color_cut_29 = diamond[(diamond['clarity_group']== '5') & (diamond['color_group']== '2') & (diamond['cut_group']== '2')]
clarity_color_cut_30 = diamond[(diamond['clarity_group']== '5') & (diamond['color_group']== '2') & (diamond['cut_group']== '3')]

data_list = [clarity_color_cut_01, clarity_color_cut_02, clarity_color_cut_03, clarity_color_cut_04, clarity_color_cut_05,
             clarity_color_cut_06, clarity_color_cut_07, clarity_color_cut_08, clarity_color_cut_09, clarity_color_cut_10,
            clarity_color_cut_11, clarity_color_cut_12, clarity_color_cut_13, clarity_color_cut_14, clarity_color_cut_15,
             clarity_color_cut_16, clarity_color_cut_17, clarity_color_cut_18, clarity_color_cut_19, clarity_color_cut_20, 
             clarity_color_cut_21, clarity_color_cut_22, clarity_color_cut_23, clarity_color_cut_24, clarity_color_cut_25, 
             clarity_color_cut_26, clarity_color_cut_27, clarity_color_cut_28, clarity_color_cut_29, clarity_color_cut_30]

def train_predict_price(data):
    model_list=[]
    for x in data:
        model = LinearRegression(normalize=True)
        diamond = x.drop(['cut', 'color', 'clarity'], axis=1)
        X = diamond[['carat', 'depth', 'table', 'x', 'y', 'z', 'cut_group', 'color_group', 'clarity_group']]
        y = diamond['price']
        model_list.append(model.fit(X, y))
    return model_list

# %%
model_list = train_predict_price(data_list)

# %%
model_list
# Out:
# [LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)]

# %%
def predict_price(list_model, data, mask_list):
    mask_list = [(data['clarity_group']== '1') & (data['color_group']== '1') & (data['cut_group']== '1'),
            (data['clarity_group']== '1') & (data['color_group']== '1') & (data['cut_group']== '2'),
            (data['clarity_group']== '1') & (data['color_group']== '1') & (data['cut_group']== '3'),
            (data['clarity_group']== '1') & (data['color_group']== '2') & (data['cut_group']== '1'),
            (data['clarity_group']== '1') & (data['color_group']== '2') & (data['cut_group']== '2'),
            (data['clarity_group']== '1') & (data['color_group']== '2') & (data['cut_group']== '3'),
            (data['clarity_group']== '2') & (data['color_group']== '1') & (data['cut_group']== '1'),
            (data['clarity_group']== '2') & (data['color_group']== '1') & (data['cut_group']== '2'),
            (data['clarity_group']== '2') & (data['color_group']== '1') & (data['cut_group']== '3'),
            (data['clarity_group']== '2') & (data['color_group']== '2') & (data['cut_group']== '1'),
            (data['clarity_group']== '2') & (data['color_group']== '2') & (data['cut_group']== '2'),
            (data['clarity_group']== '2') & (data['color_group']== '2') & (data['cut_group']== '3'),
            (data['clarity_group']== '3') & (data['color_group']== '1') & (data['cut_group']== '1'),
            (data['clarity_group']== '3') & (data['color_group']== '1') & (data['cut_group']== '2'),
            (data['clarity_group']== '3') & (data['color_group']== '1') & (data['cut_group']== '3'),
            (data['clarity_group']== '3') & (data['color_group']== '2') & (data['cut_group']== '1'),
            (data['clarity_group']== '3') & (data['color_group']== '2') & (data['cut_group']== '2'),
            (data['clarity_group']== '3') & (data['color_group']== '2') & (data['cut_group']== '3'),
            (data['clarity_group']== '4') & (data['color_group']== '1') & (data['cut_group']== '1'),
            (data['clarity_group']== '4') & (data['color_group']== '1') & (data['cut_group']== '2'),
            (data['clarity_group']== '4') & (data['color_group']== '1') & (data['cut_group']== '3'),
            (data['clarity_group']== '4') & (data['color_group']== '2') & (data['cut_group']== '1'),
            (data['clarity_group']== '4') & (data['color_group']== '2') & (data['cut_group']== '2'),
            (data['clarity_group']== '4') & (data['color_group']== '2') & (data['cut_group']== '3'),
            (data['clarity_group']== '5') & (data['color_group']== '1') & (data['cut_group']== '1'),
            (data['clarity_group']== '5') & (data['color_group']== '1') & (data['cut_group']== '2'),
            (data['clarity_group']== '5') & (data['color_group']== '1') & (data['cut_group']== '3'),
            (data['clarity_group']== '5') & (data['color_group']== '2') & (data['cut_group']== '1'),
            (data['clarity_group']== '5') & (data['color_group']== '2') & (data['cut_group']== '2'),
            (data['clarity_group']== '5') & (data['color_group']== '2') & (data['cut_group']== '3')]
    
    for i in range(len(mask_list)):
        try:
            data.loc[mask_list[i], 'price_predicted'] = list_model[i].predict(data[mask_list[i]][['carat', 'depth', 'table', 'x', 'y', 'z', 'cut_group', 'color_group', 'clarity_group']])
        except:
            pass

# %%
predict_price(model_list, rick, mask_list)

# %%
rick.sample(50)
# Out:
#       carat        cut color clarity  depth  table     x     y     z  \
# 788    1.04  Very Good     I     VS2   61.9   58.0  6.47  6.55  4.03
# 4015   1.01    Premium     I     SI1   62.8   58.0  6.40  6.34  4.00
# 1119   1.10    Premium     H     VS2   61.4   58.0  6.68  6.62  4.08
# 2103   0.75      Ideal     G    VVS2   62.0   56.0  5.79  5.85  3.61
# 2785   0.54  Very Good     I     VS2   62.3   56.0  5.17  5.22  3.24
# 4423   0.51  Very Good     F     SI2   62.7   56.0  5.07  5.10  3.19
# 2494   0.72    Premium     F     VS1   62.2   58.0  5.75  5.70  3.56
# 65     1.23      Ideal     H      IF   61.3   57.0  6.87  6.92  4.23
# 30     1.03  Very Good     I     VS1   62.9   53.0  6.45  6.50  4.07
# 1161   0.39       Good     D    VVS2   58.1   60.0  4.82  4.85  2.81
# 972    0.53      Ideal     E     VS2   61.5   56.0  5.18  5.23  3.20
# 824    0.77  Very Good     D     SI1   62.1   58.0  5.84  5.89  3.64
# 180    2.03  Very Good     I     SI2   62.8   59.0  8.04  8.08  5.06
# 1934   1.02      Ideal     G     VS1   61.6   55.0  6.53  6.46  4.00
# 4388   0.32  Very Good     D     SI1   63.1   57.0  4.38  4.37  2.76
# 4192   0.25    Premium     H    VVS1   60.1   62.0  4.11  4.08  2.46
# 4539   1.09    Premium     H     SI2   59.6   61.0  6.69  6.63  3.97
# 868    0.70  Very Good     H     SI1   58.5   65.0  5.81  5.84  3.41
# 4978   1.70      Ideal     F     VS2   62.7   55.0  7.54  7.58  4.74
# 4630   0.30  Very Good     G    VVS2   59.7   63.0  4.34  4.37  2.60
# 2051   0.51    Premium     H     SI1   60.6   59.0  5.17  5.13  3.12
# 2301   0.56  Very Good     G     VS1   60.2   56.0  5.35  5.37  3.23
# 1881   0.38  Very Good     G     VS1   61.9   56.0  4.63  4.68  2.88
# 1574   0.40  Very Good     E    VVS2   63.6   55.0  4.67  4.70  2.98
# 155    1.13      Ideal     G     SI1   61.8   55.0  6.71  6.75  4.16
# 4757   0.31    Premium     I     VS1   60.8   59.0  4.37  4.41  2.67
# 4250   1.74      Ideal     E     SI1   62.2   56.0  7.72  7.67  4.79
# 794    0.30      Ideal     F    VVS1   61.9   54.0  4.35  4.37  2.70
# 2379   0.78    Premium     H     SI2   59.7   59.0  6.03  5.97  3.58
# 1635   0.36    Premium     G     VS1   59.7   59.0  4.61  4.64  2.76
# 4888   0.70       Fair     G    VVS1   58.8   66.0  5.81  5.90  3.44
# 4893   0.90       Good     F     SI1   63.9   59.0  6.06  6.09  3.88
# 2745   1.05      Ideal     F    VVS2   62.1   54.0  6.55  6.52  4.06
# 2440   0.62      Ideal     D     SI1   60.8   59.0  5.48  5.50  3.34
# 54     0.70      Ideal     E     VS2   62.6   57.0  5.63  5.68  3.54
# 2374   0.52    Premium     G    VVS1   61.9   61.0  5.13  5.11  3.17
# 513    0.41       Good     E     SI2   63.5   55.0  4.69  4.73  2.99
# 3121   0.43    Premium     H      I1   62.0   59.0  4.83  4.78  2.98
# 4193   0.31       Good     H    VVS1   63.7   56.0  4.33  4.30  2.75
# 3004   0.61  Very Good     H    VVS2   60.5   57.0  5.52  5.54  3.35
# 2239   0.58       Fair     F      I1   66.3   55.0  5.18  5.10  3.41
# 1590   1.01  Very Good     F     SI1   63.3   59.0  6.42  6.38  4.05
# 2664   0.38      Ideal     I     SI1   61.5   56.0  4.67  4.70  2.88
# 1423   0.96    Premium     D     SI2   59.1   58.0  6.53  6.44  3.83
# 3947   0.51       Good     E     VS2   63.1   59.0  5.04  5.07  3.19
# 2702   0.39    Premium     F     SI1   60.1   59.0  4.77  4.74  2.86
# 2138   0.90    Premium     G     VS2   61.0   58.0  6.20  6.13  3.76
# 1674   1.53    Premium     H     VS2   59.8   58.0  7.49  7.52  4.49
# 1488   0.33      Ideal     D    VVS2   60.9   57.0  4.46  4.48  2.72
# 2104   1.08  Very Good     I     VS1   62.5   57.0  6.51  6.54  4.08
#
#      cut_group color_group clarity_group  price_predicted
# 788          2           2             3      5476.716673
# 4015         1           2             4      4220.222951
# 1119         1           2             3      6179.354711
# 2103         1           2             2      3848.344874
# 2785         2           2             3      1645.314075
# 4423         2           1             4      1259.755510
# 2494         1           1             3      3284.803377
# 65           1           2             1      9608.548352
# 30           2           2             3      5573.214937
# 1161         2           1             2       970.116555
# 972          1           1             3      1831.017431
# 824          2           1             4      2898.184430
# 180          2           2             4     13141.825233
# 1934         1           2             3      5579.747328
# 4388         2           1             4       308.334802
# 4192         1           2             2       166.034219
# 4539         1           2             4      4803.032540
# 868          2           2             4      1976.285596
# 4978         1           1             3     17863.393248
# 4630         2           2             2       506.881087
# 2051         1           2             4       943.719619
# 2301         2           2             3      1827.779712
# 1881         2           2             3       726.691400
# 1574         2           1             2      1085.810357
# 155          1           2             4      5337.881911
# 4757         1           2             3       354.470195
# 4250         1           1             4     12499.353580
# 794          1           1             2       447.563547
# 2379         1           2             4      2495.435997
# 1635         1           2             3       668.276229
# 4888         3           2             2      2306.936265
# 4893         2           1             4      3864.516714
# 2745         1           1             2      9704.264432
# 2440         1           1             4      1793.400459
# 54           1           1             3      3272.902242
# 2374         1           2             2      1591.074576
# 513          2           1             4       858.407876
# 3121         1           2             5       -87.338700
# 4193         2           2             2       389.112468
# 3004         2           2             2      2429.812027
# 2239         3           1             5      1047.836296
# 1590         2           1             4      4497.492905
# 2664         1           2             4       514.452188
# 1423         1           1             4      4316.169176
# 3947         2           1             3      1343.650253
# 2702         1           1             4       676.141229
# 2138         1           2             3      4534.729770
# 1674         1           2             3     10479.330093
# 1488         1           1             2       842.706234
# 2104         2           2             3      5892.215344

# %%
rick.to_csv('marcelo_diamond.csv')

# %%
diamond.loc[rick['price_predicted'] >= 20000, 'price_predicted']=diamond.price.max()
diamond.loc[rick['price_predicted'] < diamond['price'].min(), 'price_predicted']=diamond.price.min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     656         try:
# --> 657             return self._convert_to_indexer(key, axis=axis)
#     658         except TypeError as e:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, raise_missing)
#    1731                 # When setting, missing keys are not allowed, even with .loc:
# -> 1732                 return self._get_listlike_indexer(obj, axis, raise_missing=True)[1]
#    1733         else:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1546                 key = self._convert_for_reindex(key, axis)
# -> 1547             indexer = ax.get_indexer_for(key)
#    1548             keyarr = ax.reindex(keyarr)[0]
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexes\base.py in get_indexer_for(self, target, **kwargs)
#    4500         if self.is_unique:
# -> 4501             return self.get_indexer(target, **kwargs)
#    4502         indexer, _ = self.get_indexer_non_unique(target, **kwargs)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexes\range.py in get_indexer(self, target, method, limit, tolerance)
#     371             # checks/conversions/roundings are delegated to general method
# --> 372             return super().get_indexer(target, method=method, tolerance=tolerance)
#     373
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    2728             return this.get_indexer(
# -> 2729                 target, method=method, limit=limit, tolerance=tolerance
#    2730             )
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    2752
# -> 2753             indexer = self._engine.get_indexer(target._ndarray_values)
#    2754
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_indexer()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py in __hash__(self)
#    1798         raise TypeError(
# -> 1799             f"{repr(type(self).__name__)} objects are mutable, "
#    1800             f"thus they cannot be hashed"
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
#
# During handling of the above exception, another exception occurred:
#
# IndexingError                             Traceback (most recent call last)
# <ipython-input-86-8ff56e5b0ede> in <module>
# ----> 1 diamond.loc[rick['price_predicted'] >= 20000, 'price_predicted']=diamond.price.max()
#       2 diamond.loc[rick['price_predicted'] < diamond['price'].min(), 'price_predicted']=diamond.price.min()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     668         else:
#     669             key = com.apply_if_callable(key, self.obj)
# --> 670         indexer = self._get_setitem_indexer(key)
#     671         self._setitem_with_indexer(indexer, value)
#     672
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     661             if "cannot do" in str(e):
#     662                 raise
# --> 663             raise IndexingError(key)
#     664
#     665     def __setitem__(self, key, value):
#
# IndexingError: (0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Name: price_predicted, Length: 5000, dtype: bool, 'price_predicted')

# %%
predict_price(model_list, diamond, mask_list)

# %%
diamond.sample()
# Out:
#        carat    cut color clarity  depth  table  price     x     y     z  \
# 37634   0.44  Ideal     D     VS1   62.3   55.0   1235  4.85  4.88  3.03
#
#       cut_group color_group clarity_group  price_predicted
# 37634         1           1             3      1285.877079

# %%
sns.regplot(x='price', y='price_predicted', data=diamond)
sns.set_style('darkgrid')
plt.show()

# %%
diamond.loc[diamond['price_predicted'] >= 20000, 'price_predicted']=diamond.price.max()
diamond.loc[diamond['price_predicted'] < diamond['price'].min(), 'price_predicted']=diamond.price.min()

# %%
rmse = np.sqrt(mean_squared_error(diamond['price'], diamond['price_predicted']))

# %%
R2 = r2_score(diamond['price'], diamond['price_predicted'])

# %%
rmse, R2
# Out:
# (915.3489003730763, 0.9473520535538162)
