# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
from sklearn import preprocessing

# %%
pd.options.display.max_rows = 99999

# %%
# importing the Young CSV
young = pd.read_csv('data/asset-v1_IRONHACK+DAFT+202002_SAO+type@asset+block@responses.csv')

# %%
young.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock  ...   Age  Height  Weight  \
# 0      1.0  5.0   5.0                1.0  ...  20.0   163.0    48.0
# 1      2.0  3.0   5.0                4.0  ...  19.0   163.0    58.0
# 2      5.0  3.0   5.0                3.0  ...  20.0   176.0    67.0
# 3      1.0  2.0   2.0                1.0  ...  22.0   172.0    59.0
# 4      3.0  5.0   3.0                1.0  ...  20.0   170.0    59.0
#
#    Number of siblings  Gender  Left - right handed                Education  \
# ...

# %%
young.describe().T
# Out:
#                                  count        mean        std   min    25%  \
# Music                           1007.0    4.731877   0.664049   1.0    5.0
# Slow songs or fast songs        1008.0    3.328373   0.833931   1.0    3.0
# Dance                           1006.0    3.113320   1.170568   1.0    2.0
# Folk                            1005.0    2.288557   1.138916   1.0    1.0
# Country                         1005.0    2.123383   1.076136   1.0    1.0
# Classical music                 1003.0    2.956132   1.252570   1.0    2.0
# Musical                         1008.0    2.761905   1.260845   1.0    2.0
# Pop                             1007.0    3.471698   1.161400   1.0    3.0
# Rock                            1004.0    3.761952   1.184861   1.0    3.0
# Metal or Hardrock               1007.0    2.361470   1.372995   1.0    1.0
# Punk                            1002.0    2.456088   1.301105   1.0    1.0
# ...

# %%
young.isnull().sum()
# Out:
# Music                              3
# Slow songs or fast songs           2
# Dance                              4
# Folk                               5
# Country                            5
# Classical music                    7
# Musical                            2
# Pop                                3
# Rock                               6
# Metal or Hardrock                  3
# Punk                               8
# Hiphop, Rap                        4
# Reggae, Ska                        7
# Swing, Jazz                        6
# Rock n roll                        7
# Alternative                        7
# Latino                             8
# Techno, Trance                     7
# Opera                              1
# Movies                             6
# Horror                             2
# Thriller                           1
# Comedy                             3
# Romantic                           3
# Sci-fi                             2
# ...

# %%
young.dtypes
# Out:
# Music                             float64
# Slow songs or fast songs          float64
# Dance                             float64
# Folk                              float64
# Country                           float64
# Classical music                   float64
# Musical                           float64
# Pop                               float64
# Rock                              float64
# Metal or Hardrock                 float64
# Punk                              float64
# Hiphop, Rap                       float64
# Reggae, Ska                       float64
# Swing, Jazz                       float64
# Rock n roll                       float64
# Alternative                       float64
# Latino                            float64
# Techno, Trance                    float64
# Opera                             float64
# Movies                            float64
# Horror                            float64
# Thriller                          float64
# ...

# %%
young.select_dtypes('object')
# Out:
#              Smoking         Alcohol              Punctuality  \
# 0       never smoked     drink a lot      i am always on time
# 1       never smoked     drink a lot         i am often early
# 2      tried smoking     drink a lot  i am often running late
# 3      former smoker     drink a lot         i am often early
# 4      tried smoking  social drinker      i am always on time
# 5       never smoked           never         i am often early
# 6      tried smoking  social drinker         i am often early
# 7     current smoker     drink a lot      i am always on time
# 8      tried smoking  social drinker         i am often early
# 9       never smoked     drink a lot  i am often running late
# 10    current smoker  social drinker         i am often early
# 11     tried smoking           never  i am often running late
# 12     tried smoking  social drinker  i am often running late
# 13      never smoked  social drinker         i am often early
# ...

# %%
young['Smoking'].unique()
# Out:
# array(['never smoked', 'tried smoking', 'former smoker', 'current smoker',
#        nan], dtype=object)

# %%
young['Alcohol'].unique()
# Out:
# array(['drink a lot', 'social drinker', 'never', nan], dtype=object)

# %%
# Creating Age Group 0 = 15 to 19 / 1 = 19 to 25 / 2 = 25 to 30 years old
young['age_group'] = pd.cut(x=young['Age'], bins=[15, 19, 25, 30], labels=[0, 1, 2])

# %%
young['age_group'].value_counts()
# Out:
# 1    510
# 0    415
# 2     67
# Name: age_group, dtype: int64

# %%
young['Gender'] = young['Gender'].astype('category')

# %%
young['Smoking'].unique()
# Out:
# array(['never smoked', 'tried smoking', 'former smoker', 'current smoker',
#        nan], dtype=object)

# %%
for x in range(len(young['smoke_cat'])):
    if young['smoke_cat'][x] == 'never smoked':
        x = 0
    elif young['smoke_cat'][x] == 'tried smoking':
        x = 1
    elif young['smoke_cat'][x] == 'former smoker':
        x = 2
    elif young['smoke_cat'][x] == 'current smoker':
        x = 3
    else:
        x= -1
    print(x)
# Out:
# 0
# 0
# 1
# 2
# 1
# 0
# 1
# 3
# 1
# 0
# 3
# 1
# 1
# 0
# 3
# 2
# 3
# 1
# 1
# 2
# 0
# 1
# 1
# 1
# 1
# 1
# 1
# 0
# 2
# 1
# 2
# 1
# 3
# 1
# 1
# 1
# 0
# 2
# 1
# 0
# 0
# 1
# 0
# 1
# 3
# 0
# 3
# 1
# 3
# 1
# 1
# 0
# 3
# 1
# 3
# 3
# 3
# 3
# 0
# 3
# 1
# 3
# 0
# 1
# 2
# 1
# 1
# 0
# 1
# 1
# 2
# 1
# 2
# 2
# 1
# 1
# 1
# 1
# 0
# 2
# 1
# 1
# 0
# 2
# 2
# 1
# 3
# 2
# 2
# 1
# 1
# 0
# 0
# 3
# 1
# 1
# 2
# 1
# 2
# 0
# 1
# 1
# 1
# 1
# 1
# 0
# 2
# 1
# 0
# 1
# 2
# 1
# 0
# 2
# 2
# 1
# 2
# 0
# 0
# 1
# 0
# 3
# 1
# 1
# 3
# 0
# 1
# 1
# 0
# 0
# -1
# 2
# 1
# 1
# 2
# 3
# 0
# 0
# 0
# 1
# 1
# 3
# 0
# 2
# 0
# 3
# 1
# 0
# 0
# -1
# 1
# 1
# 1
# 1
# 2
# 1
# 0
# 2
# 1
# 1
# 1
# 3
# 1
# 3
# 3
# 1
# 2
# 3
# 1
# 3
# 0
# 1
# 1
# 0
# 2
# 0
# 2
# 1
# 1
# 1
# 3
# 0
# 1
# 1
# 2
# 0
# 1
# 0
# 0
# 0
# 0
# 2
# 3
# 1
# 3
# 3
# 1
# 1
# 3
# 2
# 1
# 1
# 0
# 3
# 0
# 0
# 1
# 1
# 3
# 0
# 1
# 1
# 1
# 0
# 1
# 2
# 3
# 0
# 1
# 3
# 1
# 3
# 0
# 1
# 1
# 1
# 1
# 2
# 1
# 1
# 1
# 1
# 0
# 3
# 0
# 1
# 1
# 2
# 2
# 2
# 2
# 1
# 0
# 0
# 1
# 1
# 1
# 2
# 1
# ...

# %%
young.groupby(['Music'])
