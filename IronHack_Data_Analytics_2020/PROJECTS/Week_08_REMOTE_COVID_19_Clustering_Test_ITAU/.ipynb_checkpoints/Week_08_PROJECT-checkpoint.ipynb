# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
from sklearn import preprocessing
from sklearn.decomposition import PCA
from yellowbrick.features.pca import PCADecomposition
from sklearn.cluster import DBSCAN

# %%
# Importing DataSet
young = pd.read_csv('data/asset-v1_IRONHACK+DAFT+202002_SAO+type@asset+block@responses.csv')

# %%
# Checking number of NaN records
young.isna().sum()
# Out:
# Music                       3
# Slow songs or fast songs    2
# Dance                       4
# Folk                        5
# Country                     5
#                            ..
# Left - right handed         3
# Education                   1
# Only child                  2
# Village - town              4
# House - block of flats      4
# Length: 150, dtype: int64

# %%
# Due to the small amount of NaN i dropped them
young.dropna(inplace=True)

# %%
# Checking unique values of this specific column
young['Smoking'].unique()
# Out:
# array(['never smoked', 'tried smoking', 'current smoker', 'former smoker'],
#       dtype=object)

# %%
# function to categorize the Smoke column
def cat_smoke(x):
    """
    Function to categorize the types of smokers
    
    """
    if (x == 'never smoked'):
        return '1'
    elif (x == 'tried smoking'):
        return '2'
    elif (x == 'former smoker'):
        return '3'
    elif (x == 'current smoker'):
        return '4'

# %%
# Executing function and adding a smoke_group column to the DataSet
young['smoke_group'] = young['Smoking'].apply(cat_smoke)

# %%
# Dropping the original Smoke column
young.drop('Smoking', axis=1, inplace=True)

# %%
# Checking unique values of this specific column
young['Alcohol'].unique()
# Out:
# array(['drink a lot', 'social drinker', 'never'], dtype=object)

# %%
# Function to categorize the Alcohol column
def cat_alcohol(x):
    """
    Function to categorize alcohol consumption
    
    """
    if (x == 'never'):
        return '1'
    elif (x == 'social drinker'):
        return '2'
    elif (x == 'drink a lot'):
        return '3'

# %%
# Executing function and adding a acohol_group column to the DataSet
young['alcohol_group'] = young['Alcohol'].apply(cat_alcohol)

# %%
# Dropping the original Alcohol column
young.drop('Alcohol', axis=1, inplace=True)

# %%
# Checking unique values of this specific column
young['Punctuality'].unique()
# Out:
# array(['i am always on time', 'i am often early',
#        'i am often running late'], dtype=object)

# %%
# function to categorize the Punctuality column
def cat_punct(x):
    """
    Function to categorize punctuality
    
    """
    if (x == 'i am often early'):
        return '1'
    elif (x == 'i am always on time'):
        return '2'
    elif (x == 'i am often running late'):
        return '3'

# %%
# Executing function and adding a punctuality_group column to the DataSet
young['punctuality_group'] = young['Punctuality'].apply(cat_punct)

# %%
# Dropping the original Punctuality column
young.drop('Punctuality', axis=1, inplace=True)

# %%
# Dropping a few columns i thought to be insignificant to the data
young.drop(['Only child', 'Village - town', 'House - block of flats', 'Left - right handed', 'Lying'], axis=1, inplace=True)

# %%
# Checking unique values of this specific column
young['Education'].unique()
# Out:
# array(['college/bachelor degree', 'secondary school', 'primary school',
#        'masters degree', 'doctorate degree',
#        'currently a primary school pupil'], dtype=object)

# %%
# function to categorize the Education column
def cat_edu(x):
    """
    Function to categorize degree of education
    
    """
    if (x == 'currently a primary school pupil'):
        return '1'
    elif (x == 'primary school'):
        return '2'
    elif (x == 'secondary school'):
        return '3'
    elif (x == 'college/bachelor degree'):
        return '4'
    elif (x == 'masters degree'):
        return '5'
    elif (x == 'doctorate degree'):
        return '6'

# %%
# Executing function and adding a education_group column to the DataSet
young['education_group'] = young['Education'].apply(cat_edu)

# %%
# Dropping the original Education column
young.drop(['Education'], axis=1, inplace=True)

# %%
# Selecting the object type columns
young.select_dtypes('object').columns
# Out:
# Index(['Internet usage', 'Gender', 'smoke_group', 'alcohol_group',
#        'punctuality_group', 'education_group'],
#       dtype='object')

# %%
# Checking unique values of this specific column
young['Internet usage'].unique()
# Out:
# array(['few hours a day', 'less than an hour a day', 'most of the day'],
#       dtype=object)

# %%
# function to categorize the Internet Usage column
def cat_internet(x):
    """
    Function to categorize internet usage
    
    """
    if (x == 'less than an hour a day'):
        return '1'
    elif (x == 'few hours a day'):
        return '2'
    elif (x == 'most of the day'):
        return '3'

# %%
# Executing function and adding a internet_group column to the DataSet
young['internet_group'] = young['Internet usage'].apply(cat_internet)

# %%
# Dropping the original Internet Usage column
young.drop(['Internet usage'], axis=1, inplace=True)

# %%
# Checking unique values of this specific column
young['Gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
# function to categorize the Gender column
def cat_gender(x):
    """
    Function to categorize gender
    
    """
    if (x == 'male'):
        return '0'
    elif (x == 'female'):
        return '1'

# %%
# Executing function and adding a gender_group column to the DataSet
young['gender_group'] = young['Gender'].apply(cat_gender)

# %%
# Dropping the original Gender column
young.drop(['Gender'], axis=1, inplace=True)

# %%
# Standarizing the DataSet
young_scale = StandardScaler().fit_transform(young)
# Out:
# C:\Users\LIBRE\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int32, int64, float64, object were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\LIBRE\Anaconda3\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype int32, int64, float64, object were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
# Checking the inertia for the kmeans, to help define the optimal number of clusters for this DataSet
for n_clusters in range(1,10):
    kmeans = KMeans(n_clusters)
    kmeans.fit(young_scale)
    print(kmeans.inertia_)
# Out:
# 98404.0
# 93493.01245983492
# 90994.2061926609
# 88730.80146031488
# 87677.07981154995
# 86764.3386473783
# 86008.2493038219
# 85489.44726431342
# 84856.37241546558

# %%
# Utilizing the Elbow Visualizer to confirm the resuts above and 
# help define the optimal number os clusters for hits DataSet
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,12))

visualizer.fit(young_scale) 
visualizer.show()

# %%
# Running kmeans with the number of clusters we got from the tests above
kmeans = KMeans(4)
kmeans.fit(young_scale)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
# checking kmeans labels
kmeans.labels_
# Out:
# array([1, 0, 3, 3, 2, 1, 0, 1, 1, 3, 3, 1, 1, 1, 2, 0, 2, 0, 1, 1, 1, 2,
#        0, 1, 0, 3, 1, 2, 2, 1, 3, 3, 3, 1, 2, 2, 1, 1, 1, 1, 3, 2, 2, 2,
#        3, 3, 0, 2, 1, 2, 1, 0, 0, 1, 1, 1, 0, 1, 2, 2, 1, 1, 1, 2, 3, 2,
#        2, 3, 3, 1, 3, 0, 0, 0, 0, 3, 1, 0, 2, 3, 2, 3, 0, 2, 3, 3, 1, 3,
#        3, 3, 3, 2, 0, 3, 3, 3, 3, 2, 2, 3, 0, 3, 3, 3, 2, 2, 1, 3, 3, 2,
#        2, 0, 2, 0, 3, 3, 0, 1, 0, 3, 0, 1, 3, 0, 3, 0, 2, 0, 3, 3, 2, 1,
#        3, 1, 3, 3, 3, 1, 3, 0, 0, 1, 0, 0, 1, 3, 3, 2, 3, 1, 1, 2, 2, 3,
#        0, 3, 0, 2, 2, 3, 1, 0, 2, 3, 3, 0, 1, 3, 3, 3, 2, 1, 1, 0, 1, 1,
#        1, 2, 1, 1, 1, 3, 0, 1, 1, 0, 3, 1, 1, 1, 1, 2, 1, 3, 0, 3, 2, 1,
#        2, 0, 2, 1, 2, 1, 0, 1, 1, 1, 1, 2, 1, 3, 1, 0, 0, 1, 1, 0, 1, 1,
#        1, 3, 1, 2, 0, 2, 1, 1, 1, 3, 3, 1, 2, 1, 1, 1, 0, 3, 1, 3, 2, 3,
#        0, 3, 3, 0, 1, 1, 1, 0, 2, 0, 0, 3, 1, 0, 0, 1, 2, 3, 0, 0, 1, 2,
#        0, 1, 2, 2, 1, 3, 0, 2, 0, 1, 1, 1, 2, 3, 1, 0, 0, 0, 2, 0, 0, 3,
#        3, 1, 1, 3, 1, 0, 1, 3, 0, 1, 1, 0, 1, 3, 3, 2, 3, 3, 3, 1, 3, 0,
#        0, 3, 0, 1, 0, 3, 0, 1, 1, 3, 3, 1, 0, 3, 1, 0, 2, 1, 1, 1, 0, 0,
#        3, 0, 2, 3, 1, 3, 1, 1, 0, 0, 2, 0, 1, 2, 1, 1, 3, 3, 0, 1, 3, 3,
#        3, 3, 3, 1, 0, 0, 2, 2, 2, 0, 3, 0, 1, 0, 1, 1, 1, 0, 3, 3, 2, 1,
#        0, 2, 1, 2, 1, 2, 1, 3, 0, 2, 2, 3, 1, 2, 1, 1, 1, 2, 0, 3, 1, 1,
#        0, 1, 3, 0, 1, 1, 0, 0, 2, 3, 1, 0, 1, 2, 2, 1, 3, 3, 0, 0, 0, 0,
#        1, 3, 1, 2, 0, 1, 0, 1, 1, 0, 2, 0, 0, 2, 1, 1, 0, 0, 0, 1, 0, 1,
#        0, 3, 2, 1, 0, 0, 2, 0, 1, 2, 1, 1, 2, 3, 2, 0, 1, 3, 3, 0, 1, 2,
#        3, 1, 2, 0, 1, 3, 2, 0, 1, 2, 2, 1, 3, 1, 1, 2, 2, 1, 2, 3, 1, 0,
#        3, 2, 1, 2, 2, 3, 0, 2, 3, 3, 0, 0, 1, 1, 2, 3, 3, 2, 2, 3, 2, 0,
#        2, 3, 2, 3, 1, 3, 0, 1, 0, 2, 0, 2, 3, 0, 0, 2, 3, 0, 1, 2, 3, 1,
#        1, 2, 3, 2, 2, 0, 3, 0, 2, 0, 2, 2, 0, 2, 2, 1, 1, 1, 1, 0, 0, 0,
#        2, 2, 1, 2, 0, 0, 1, 1, 3, 1, 0, 3, 3, 1, 2, 0, 2, 0, 0, 1, 1, 1,
#        2, 1, 0, 1, 0, 1, 2, 1, 0, 0, 0, 0, 0, 0, 0, 3, 3, 1, 0, 1, 2, 2,
#        2, 0, 1, 3, 1, 1, 0, 1, 0, 0, 1, 2, 0, 1, 3, 2, 1, 2, 1, 1, 2, 1,
#        3, 3, 1, 0, 0, 1, 1, 3, 1, 0, 1, 3, 1, 0, 1, 1, 3, 2, 3, 1, 1, 2,
#        3, 2, 0, 3, 2, 3, 1, 2, 0, 0, 3, 3, 3, 2, 1, 0, 3, 2, 3, 0, 3, 3,
#        2, 0, 0, 0, 0, 2, 1, 1, 3, 0, 1, 3, 1, 3])

# %%
# Generating the kmeans predict
predicted = kmeans.predict(young_scale)

# %%
# Plotting scatter plots to test for Music by Age
fig, ax = plt.subplots(1, 2, figsize=(13,5))
sns.set_context("talk")
sns.scatterplot(young['Music'], young['Age'], hue=kmeans.labels_, ax=ax[0])
sns.scatterplot(young['Music'], young['Age'], hue=predicted, ax=ax[1])
sns.set_style('darkgrid')

# %%
# Training the model for PCA
pca = PCA(2)
pca.fit(young_scale)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
# Storing the resulting columns in separate variables
pc1 = pca.transform(young_scale)[:, 0]
pc2 = pca.transform(young_scale)[:, 1]

# %%
# concatenating the pca results with its respective columns from the original DataSet
coord = sorted(list(zip(pca.components_[0],pca.components_[1], young.columns)), key = lambda x: x[0])
coord
# Out:
# [(-0.24765520986371423, -0.051909143627619, 'gender_group'),
#  (-0.20588740543407666, -0.06059286723791367, 'Life struggles'),
#  (-0.1801073107404234, 0.021544601700315632, 'Romantic'),
#  (-0.15531629545790154, 0.014789703147311992, 'Shopping'),
#  (-0.14355019082839693, 0.11794371928696779, 'Theatre'),
#  (-0.1417035104253016, 0.05641402091192441, 'Fantasy/Fairy tales'),
#  (-0.14069289836813026, 0.11455516209219911, 'Dancing'),
#  (-0.13788898480545853, -0.035178172463714824, 'Storm'),
#  (-0.1367663391559387, -0.044830220346358224, 'Darkness'),
#  (-0.13572397849884177, 0.07300479167521523, 'Writing notes'),
#  (-0.1345115020047421, 0.06321618900938399, 'Reading'),
#  (-0.12851417278762242, 0.11171176176702478, 'Musical'),
#  (-0.1259809751284751, 0.10406822186609131, 'Latino'),
#  (-0.11935856822524758, -0.058529149656185116, 'Dangerous dogs'),
#  (-0.1170134263187563, 0.13436481295213415, 'Art exhibitions'),
#  (-0.11478271254411959, -0.0502005424360059, 'Spiders'),
#  (-0.10724993200487999, -0.045441009021477886, 'Snakes'),
#  (-0.10650991216463296, 0.06064150699222207, 'Children'),
#  (-0.10527032156435276, -0.039220209072448844, 'Rats'),
#  (-0.10255161564610407, 0.03521990812257689, 'God'),
#  (-0.09992319728754155, 0.04247664029881453, 'Empathy'),
#  (-0.09991871833892778, 0.07442725344297411, 'Giving'),
#  (-0.09649542161186708, -0.01529513799286141, 'Celebrities'),
#  (-0.09568656874684908, 0.09103594166150311, 'Biology'),
#  (-0.09548620761565366, 0.010343646718028118, 'Health'),
#  (-0.09522247375265903, 0.02661697033984264, 'Shopping centres'),
#  (-0.09420578150228012, 0.0505734887833418, 'Animated'),
#  (-0.09226317126305625, 0.056896274797619294, 'Gardening'),
#  (-0.090329711886836, 0.0035929427047174224, 'Compassion to animals'),
#  (-0.08936062678076052, 0.052160725117093576, "Parents' advice"),
#  (-0.0872874061694116, 0.11013610948079662, 'Foreign languages'),
#  (-0.0864032649446787, -0.050961270170183155, 'Flying'),
#  (-0.08627890346913637, -0.028943526242663473, 'Decision making'),
#  (-0.08593302882747109, -0.08233139819426025, 'Mood swings'),
#  (-0.08466460665688592, 0.013878502777143486, 'Questionnaires or polls'),
#  (-0.08383340892596246, 0.017267023304820252, 'Pop'),
#  (-0.08303886944954697, 0.05385867766695393, 'Finding lost valuables'),
#  (-0.08060647227024609, 0.10364089439269046, 'Countryside, outdoors'),
#  (-0.07908600881150712, 0.04512359481492819, 'Appearence and gestures'),
#  (-0.07758217619175646, 0.09776734496347918, 'Medicine'),
#  (-0.07318443103312812, 0.07407113906351645, 'Prioritising workload'),
#  (-0.07136186215480159, 0.1004730416302079, 'Psychology'),
#  (-0.07097590581206248, 0.03488575782984439, 'Final judgement'),
#  (-0.06999104552180979, 0.06611307383708777, 'Friends versus money'),
#  (-0.06998589900302438, -0.12128702859543081, 'Public speaking'),
#  (-0.06885698211450439, -0.029691557139937656, 'Ageing'),
#  (-0.06789039451977376, 0.12080290917453426, 'Workaholism'),
#  (-0.06650910389116252, 0.098277450203356, 'Religion'),
#  (-0.065528669802042, 0.1134293495281956, 'Folk'),
#  (-0.06544186880790352, 0.06773544523459993, 'Writing'),
#  (-0.06444479689046789, 0.11134120701756733, 'Healthy eating'),
#  (-0.061526700734831505, 0.02171021844157341, 'Pets'),
#  (-0.05973860513149458, 0.04354304522893143, 'Borrowed stuff'),
#  (-0.05890175300680849, 0.12335607336789338, 'Charity'),
#  (-0.05791878578326921, 0.015461995558275007, 'Finances'),
#  (-0.05629400038838308, 0.04972741152020512, 'Spending on looks'),
#  (-0.05492187372625987, 0.11515756136478855, 'Musical instruments'),
#  (-0.0542580312996062, -0.11255507681658326, 'Fear of public speaking'),
#  (-0.052530931492276195, 0.0017528667753689575, 'Self-criticism'),
#  (-0.05252114990321236, 0.14961597204295884, 'Swing, Jazz'),
#  (-0.05236148877603657, 0.1404555507118092, 'Opera'),
#  (-0.05085658048032131, 0.0005678193090176802, 'Unpopularity'),
#  (-0.05082679769898178, 0.08753553463646153, 'Reliability'),
#  (-0.049811862730919546, 0.1363083935906853, 'Classical music'),
#  (-0.048487101270424104, -0.08340147109193012, 'Loneliness'),
#  (-0.04830029690405121, 0.06805126573485165, 'Chemistry'),
#  (-0.04803606002415409, -0.058367069368231106, 'Heights'),
#  (-0.046477059514662813, -0.03789251070449643, 'Hypochondria'),
#  (-0.04540264011840948, 0.07415518604095421, 'Dance'),
#  (-0.04517533098522292, -0.07221883278006894, 'Getting angry'),
#  (-0.03911544967935972, 0.05238868496346667, 'Music'),
#  (-0.03275832067474318, 0.07897460435396556, 'Keeping promises'),
#  (-0.02453194278079167, 0.0554989380334771, 'Thinking ahead'),
#  (-0.023174288749640892, 0.07219398918843059, 'Judgment calls'),
#  (-0.019398377317979214, 0.04353143848909525, 'Comedy'),
#  (-0.01897369336965565, 0.11101568633960163, 'Spending on healthy eating'),
#  (-0.0159910588230837, 0.11746361154677629, 'Rock n roll'),
#  (-0.014523286797925626, -0.06060772887628896, 'Changing the past'),
#  (-0.014166404060346803, 0.08979689562360693, 'Elections'),
#  (-0.013461395512165224, 0.11133487068171034, 'Fun with friends'),
#  (-0.00836182240450724, 0.05687917266198182, 'Movies'),
#  (-0.008131588968476794, 0.06999898352628603, 'education_group'),
#  (-0.007696673657432035, 0.039519598222091536, 'Number of siblings'),
#  (-0.0060664323218830515,
#   -0.03380808456307034,
#   'Responding to a serious letter'),
#  (-0.0022660282596455614, 0.0009928438176338567, 'Loss of interest'),
#  (-0.0021983016087799476, 0.07691513888386883, 'Alternative'),
#  (-0.0007765197741222255, -0.05528691427164284, 'Getting up'),
#  (0.000487122850909697, 0.006026872411048796, 'punctuality_group'),
#  (0.0005338367627120075, 0.12194459860066792, 'Law'),
#  (0.0021402507172933395, 0.13570792071267068, 'Number of friends'),
#  (0.0031243325218537742, 0.13704905665383893, 'Socializing'),
#  (0.00369643671319439, 0.10383096871487321, 'Country'),
#  (0.004866277772857395, 0.20741664566611595, 'cluster'),
#  (0.010042842096302853, 0.1165466626404254, 'Daily events'),
#  (0.010071971242788686, 0.10803130270397894, 'Knowing the right people'),
#  (0.010775142635993735, 0.10741452030626697, 'Reggae, Ska'),
#  (0.013338000048837121, -0.020949761362370225, 'Eating to survive'),
#  (0.01492622746791524, 0.06552971845406308, 'Age'),
#  (0.015000901342033328, 0.14779473684988603, 'Energy levels'),
#  (0.016389169562103043, 0.03052690866454703, 'Achievements'),
#  (0.01698509614369981, 0.12516144015385183, 'Geography'),
#  (0.01835839725517131, 0.13372298287589784, 'History'),
#  (0.01891509639887682, 0.05139948716886423, 'Rock'),
#  (0.018994909369521074, -0.053811155943244045, 'Fake'),
#  (0.019318309476516138, 0.12762486052961047, 'Happiness in life'),
#  (0.01968463978436231, 0.1769777887236903, 'Interests or hobbies'),
#  (0.021085367753457363, 0.08523858528314938, 'Economy Management'),
#  (0.022594334119793846, 0.06224927464170631, 'Hiphop, Rap'),
#  (0.024298034901441834, 0.05104782000852022, 'Dreams'),
#  (0.024380219745266555, 0.1235635429691739, 'Documentary'),
#  (0.03143324737329214, 0.048995267739913584, 'Waiting'),
#  (0.03240718560715188, 0.0893304156699135, 'Personality'),
#  (0.03315066950448759, 0.05340787796658658, 'Techno, Trance'),
#  (0.03512497060060783, -0.006875675351867409, 'smoke_group'),
#  (0.038143293397445606, 0.0867919753995725, 'Assertiveness'),
#  (0.04683900645483175, 0.0401266145684812, 'Punk'),
#  (0.05055989535546043, 0.10423430683369006, 'New environment'),
#  (0.050581205766698355, 0.06441213823998515, 'Passive sport'),
#  (0.05101019317743028, 0.05690127962740008, 'Branded clothing'),
#  (0.05288482107977769, 0.13903025670963673, 'Active sport'),
#  (0.05474318404035821, -0.01727766472038168, 'Cheating in school'),
#  (0.055959690562730834, 0.007729434253663621, 'alcohol_group'),
#  (0.06092423968948647, 0.013197086148250912, 'Slow songs or fast songs'),
#  (0.062363683529630565, 0.13531890452968814, 'Politics'),
#  (0.0627509768542796, 0.020587658169131096, 'Internet'),
#  (0.06739900309655965, 0.09049865250078244, 'Mathematics'),
#  (0.06740479456886785, 0.05572203692171906, 'Funniness'),
#  (0.07035260925375028, -0.04472868466229148, 'internet_group'),
#  (0.0703916909892476, -0.024949692788562166, 'Criminal damage'),
#  (0.07699170364958262, 0.0699994933541582, 'Entertainment spending'),
#  (0.08061978813881619, 0.015338112746293974, 'Horror'),
#  (0.08347548499468166, 0.146537669946116, 'Adrenaline sports'),
#  (0.0880872471002326, 0.02339032281381331, 'Thriller'),
#  (0.09083811708765506, 0.12288391857595556, 'Physics'),
#  (0.09131894353112804, 0.039437878180511, 'Metal or Hardrock'),
#  (0.10235570158049956, 0.07744349911487619, 'Spending on gadgets'),
#  (0.10518103818578602, 0.15335807742954086, 'Science and technology'),
#  (0.11176735543358475, 0.06491711413759577, 'Sci-fi'),
#  (0.1136563534879548, 0.10492278953367548, 'Western'),
#  (0.11802048469171002, 0.02732695760177737, 'Small - big dogs'),
#  (0.12294558216567057, 0.08145468008900826, 'War'),
#  (0.13644241580635982, 0.06661841901254907, 'Action'),
#  (0.14054141692530758, 0.0985591499070942, 'Cars'),
#  (0.1502544791497492, 0.07876351081326646, 'PC'),
#  (0.18603773627305473, 0.04911331802205692, 'Weight'),
#  (0.20323451401837966, 0.03762774584209152, 'Height')]

# %%
# Extracting one row from the results, with a specific key characteristic
caract = 'Horror'
ponto = [item for item in coord if caract in item[2]]
x = ponto[0][0] * 100
y = ponto[0][1] * 100
ponto
# Out:
# [(0.08061978813881619, 0.015338112746293974, 'Horror')]

# %%
# Plotting that characteristic from above in a different color, to better visualize the cluster groups
sns.set_context("talk")
sns.scatterplot(pc1, pc2, hue=kmeans.labels_)
plt.scatter(x, y, color='r')
sns.set_style('darkgrid')

# %%
# Plotting the PCA results with the kmeans labels
sns.set_context("talk")
sns.scatterplot(pc1, pc2, hue=kmeans.labels_)
sns.set_style('darkgrid')

# %%
# Plotting two scatter plots, with kmeans labels and kmeans predicted
fig, ax = plt.subplots(1, 2, figsize=(13,5))
ax[0].scatter(pc1, pc2, c=kmeans.labels_)
ax[1].scatter(pc1, pc2, c=predicted )

ax[0].set_title('Real')
ax[1].set_title('Predicted')
# Out:
# Text(0.5, 1.0, 'Predicted')

# %%
# Running YellowBrick visualizer to check the clusters
visualizer = PCADecomposition(scale=True, proj_features=True,)
components = visualizer.fit_transform(young_scale, kmeans.labels_)
    
visualizer.show()

# %%
# running DBSCAN
db = DBSCAN(eps=0.3, min_samples=10)
db.fit(young_scale)
# Out:
# DBSCAN(algorithm='auto', eps=0.3, leaf_size=30, metric='euclidean',
#     metric_params=None, min_samples=10, n_jobs=None, p=None)

# %%
# Storing DBSCAN in a variable
labels = DBSCAN(eps=0.3, min_samples=10).fit_predict(young_scale)

# %%
# Plotting the DBSCAN
plt.scatter(young_scale[:, 0], young_scale[:, 1], c=labels);

# %%
# Adding a cluster column to the original DataSet
young['cluster'] = kmeans.labels_

# %%
# Grouping the original DataSet by the new Cluster column, calculating the mean of each column to check the clustering
young.groupby('cluster').mean()
# Out:
#             Music  Slow songs or fast songs     Dance      Folk   Country  \
# cluster
# 0        4.592814                  3.485030  2.958084  1.760479  1.976048
# 1        4.886256                  3.293839  3.563981  2.080569  1.805687
# 2        4.817518                  3.277372  3.189781  2.839416  2.708029
# 3        4.729560                  3.113208  2.465409  2.540881  2.169811
#
#          Classical music   Musical       Pop      Rock  Metal or Hardrock  \
# cluster
# 0               2.461078  1.976048  3.179641  3.736527           2.646707
# 1               2.483412  3.028436  4.014218  3.473934           1.682464
# 2               3.773723  3.189781  3.299270  4.116788           3.021898
# 3               3.509434  2.855346  3.119497  3.974843           2.364780
#
#          ...  Shopping centres  Branded clothing  Entertainment spending  \
# cluster  ...
# 0        ...          2.886228          3.377246                3.562874
# 1        ...          4.018957          3.213270                3.303318
# 2        ...          3.014599          2.985401                3.306569
# 3        ...          2.849057          2.446541                2.553459
#
#          Spending on looks  Spending on gadgets  Spending on healthy eating  \
# cluster
# 0                 3.023952             3.437126                    3.347305
# 1                 3.734597             2.720379                    3.644550
# 2                 2.824818             3.167883                    3.810219
# 3                 2.559748             2.132075                    3.264151
#
#                Age      Height     Weight  Number of siblings
# cluster
# 0        20.179641  181.317365  76.886228            1.281437
# 1        19.971564  168.146919  58.194313            1.194313
# 2        21.335766  177.109489  71.766423            1.467153
# 3        20.194969  168.943396  60.452830            1.314465
#
# [4 rows x 139 columns]
