# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %%
## Opening the CSV file from the first DataFrame
df = pd.read_csv('events_data.csv')

# %%
## Checking the unique values from 'city' column
df['city'].unique()
# Out:
# array(['seattle', 'houston', 'newyork', 'detroit', 'losangeles',
#        'orlando', 'sanfrancisco', 'sandiego'], dtype=object)

# %%
## cleanning data from 'city' column for better Web Scrapping later
df['city'] = df['city'].replace({'newyork':'new york',
                                 'losangeles':'los angeles',
                                 'sanfrancisco':'san francisco',
                                 'sandiego':'san diego'})

# %%
df['city'].unique()
# Out:
# array(['seattle', 'houston', 'new york', 'detroit', 'los angeles',
#        'orlando', 'san francisco', 'san diego'], dtype=object)

# %%
## Creating a new DataFrame with only a few columns from the original DataFrame
## Assigning new column names
new_df = pd.DataFrame()
new_df[['event_name', 'date', 'description', 'line_up', 'event_link', 'place', 'city', 'event_coordinates']] = df[['event_name', 'date', 'description', 'lineup', 'link', 'place', 'city', 'coordinates']]

# %%
## Openning the second DataFrame
df_parks = pd.read_csv('parks_data.csv')

# %%
df_parks.head(2)
# Out:
#    Unnamed: 0                                    address           id  \
# 0           0  140 Stewart Ave, 11237 New York, New York  115196040.0
# 1           1  140 Stewart Ave, 11237 New York, New York  115197387.0
#
#                            name  isBookable  isCampground  \
# 0     Camp Gateway- Brooklyn Ny        True          True
# 1  Camp Gateway - Staten Island        True          True
#
#                   location  latitude  longitude  \
# 0  East New York, New York   40.5958   -73.8858
# 1    Bensonhurst, New York   40.6036   -74.0588
#
#                                                  url  \
# 0  https://www.rei.com/campgrounds/camp/115196040...
# 1  https://www.rei.com/campgrounds/camp/115197387...
#
#                                               imgUrl  numCampsites
# 0  https://cdn.recreation.gov/public/images/69035...          45.0
# 1  https://cdn.recreation.gov/public/2018/08/16/2...           7.0

# %%
## Adding some columns from the second DataFrame to our new DataFrame
new_df[['park_name', 'park_link', 'park_latitude', 'park_longitude']] = df_parks[['name', 'url', 'latitude', 'longitude']]

# %%
new_df.head(2)
# Out:
#                                           event_name      date  \
# 0  The Breakfast Club - New Years Day 2020 with J...  1/1/2020
# 1  Chillography and Re-bar present Dub Techno All...  1/3/2020
#
#                                          description  \
# 0  We're back! What started at ETG has been carry...
# 1  The perfect way to chill after the end of 2019...
#
#                                              line_up  \
# 0  John Tejada, Tara Brooks, Jay Tripwire, Mary D...
# 1  Summit Dub, Alex Flores, Waste Management, Dan...
#
#                                        event_link            place     city  \
# 0  https://www.residentadvisor.net/events/1358885  The Monkey Loft  seattle
# 1  https://www.residentadvisor.net/events/1365599           Re-Bar  seattle
#
#                 event_coordinates                     park_name  \
# 0    ('47.577129', '-122.334469')     Camp Gateway- Brooklyn Ny
# 1  ('47.6166458', '-122.3310731')  Camp Gateway - Staten Island
#
#                                            park_link  park_latitude  \
# 0  https://www.rei.com/campgrounds/camp/115196040...        40.5958
# 1  https://www.rei.com/campgrounds/camp/115197387...        40.6036
#
#    park_longitude
# 0        -73.8858
# 1        -74.0588

# %% [markdown]
# ## Web Scrapping TripAdvisor for attractions in each event city

# %%
## Function to insert Name of a city and return the TripAdvisor´s page for that city´s attractions url

def find_attraction(cities):
    """
    Function that receives a string with the name of a city 
    and returns a url from TripAdvisor´s Attractions pages.
    
    The function uses BeautifulSoup and Selenium to retrieve the specific
    page of attractions of a city from TripAdvisor
    
    """

cities = new_df['city'].unique()
cities_links = []
for city in cities:
    url = 'https://www.tripadvisor.com.br/Attractions'
    trip = BeautifulSoup(requests.get(url).content)
    driver = webdriver.Chrome()
    driver.get(url)
    element = driver.find_element_by_class_name('typeahead_input')
    element.send_keys(city)
    element.send_keys(Keys.RETURN)
    time.sleep(5)
    cities_links.append(str(driver.current_url))
    print (driver.current_url)
    driver.close()
# Out:
# https://www.tripadvisor.com.br/Attractions-g60878-Activities-Seattle_Washington.html
# https://www.tripadvisor.com.br/Attractions-g56003-Activities-Houston_Texas.html
# https://www.tripadvisor.com.br/Attractions-g60763-Activities-New_York_City_New_York.html
# https://www.tripadvisor.com.br/Attractions-g42139-Activities-Detroit_Michigan.html
# https://www.tripadvisor.com.br/Attractions-g32655-Activities-Los_Angeles_California.html
# https://www.tripadvisor.com.br/Attractions-g34515-Activities-Orlando_Florida.html
# https://www.tripadvisor.com.br/Attractions-g60713-Activities-San_Francisco_California.html
# https://www.tripadvisor.com.br/Attractions-g60750-Activities-San_Diego_California.html

# %%
## Function to add new column with the city attraction links

def add_att_links(row):
    """
    This function insert the values from the 'cities_links' list,
    to a new column in the DataFrame by condition from the 'city' column
    
    """
    if row['city'] == 'seattle':
        return cities_links[0]
    elif row['city'] == 'houston':
        return cities_links[1]
    elif row['city'] == 'new york':
        return cities_links[2]
    elif row['city'] == 'detroit':
        return cities_links[3]
    elif row['city'] == 'los angeles':
        return cities_links[4]
    elif row['city'] == 'orlando':
        return cities_links[5]
    elif row['city'] == 'san francisco':
        return cities_links[6]
    elif row['city'] == 'san diego':
        return cities_links[7]

# %%
## Applying the function and creating a new column

new_df['attracion_link'] = new_df.apply(lambda row: add_att_links(row), axis=1)

# %%
new_df.sample(10)
# Out:
#                                              event_name       date  \
# 884                                          Synthicide  2/13/2020
# 1856            Lane 8 - Brightest Lights Tour (Friday)   6/5/2020
# 2674               Technometrik After Hours Still Going  3/13/2020
# 1932                                     Newly Centered   1/4/2020
# 455   Mike Dunn / David Kiss b2b Willy Soul in Paradise  1/18/2020
# 3237                                          DJ Gigola  2/29/2020
# 757   Make Mistakes Release Party with Russo / Kels ...   2/6/2020
# 2791                           Technometrik After Hours  3/28/2020
# 1099                                  13-Side: Brooklyn  2/22/2020
# 664   Deep Root Sessions At Public Arts with Dean Mi...  1/31/2020
#
#                                             description  \
# 884   DANCEABLE SYNTH-DRIVEN SETS BY /  /  /  / NGHT...
# 1856                     $46.001st release **SOLD OUT**
# 2674                               $15.00Advance ticket
# 1932  Newly centered is a culmination of Detroit art...
# 455   Accomplished Chicago house DJ / producer Mike ...
# 3237  Thrilled to have our friend DJ Gigola, who is ...
# 757   celebrating the release of "Belly of the Whale...
# 2791                               $15.00Advance ticket
# 1099  13-Side makes there first official NYC debut a...
# 664   This coming January 31st Deep Root Sessions we...
#
#                                                 line_up  \
# 884                NGHTCRWLR, Octonomy, Confines, Andi
# 1856                                             Lane 8
# 2674                                      BERLIN TECHNO
# 1932  CoveLove, Jams With Dave, Trey Priest, Tammy L...
# 455                   Mike Dunn, David Kiss, Willy Soul
# 3237                   DJ Gigola , Other Artists - TBA
# 757              Derek Russo, Kels Davidson, POSI-TRACK
# 2791                                      BERLIN TECHNO
# 1099          13-Side, , L&L&L Record Club, , Kyle Ryvn
# 664                                       Dean Mickoski
#
#                                           event_link  \
# 884   https://www.residentadvisor.net/events/1371174
# 1856  https://www.residentadvisor.net/events/1328537
# 2674  https://www.residentadvisor.net/events/1393841
# 1932  https://www.residentadvisor.net/events/1365290
# 455   https://www.residentadvisor.net/events/1373777
# 3237  https://www.residentadvisor.net/events/1394472
# 757   https://www.residentadvisor.net/events/1378782
# 2791  https://www.residentadvisor.net/events/1400230
# 1099  https://www.residentadvisor.net/events/1393063
# 664   https://www.residentadvisor.net/events/1374969
#
#                           place           city  \
# 884       Bossa Nova Civic Club       new york
# 1856            Brooklyn Mirage       new york
# 2674          TBA - Downtown LA    los angeles
# 1932            Tangent Gallery        detroit
# 455               Paradise Club       new york
# 3237                    RS94109  san francisco
# 757   Flowers For All Occasions       new york
# 2791               Downtown Loc    los angeles
# 1099              The Paper Box       new york
# 664                 Public Arts       new york
#
#                               event_coordinates                  park_name  \
# 884        ('40.69797655', '-73.9279600167073')       Wildwood Picnic Site
# 1856              ('40.7105692', '-73.9263982')         Fremont Campground
# 2674                                        NaN                        NaN
# 1932  ('42.3724111616162', '-83.0638446969697')       Wildwood Picnic Site
# 455         ('40.75923265', '-73.984077268162')    Theodore Roosevelt Home
# 3237  ('37.7854574807692', '-122.417853961538')                        NaN
# 757               ('40.6937226', '-73.9298373')               Falcon Group
# 2791                                        NaN                        NaN
# 1099       ('40.71088525', '-73.9366188656301')    Paul Little Picnic Site
# 664                ('40.723034', '-73.9920355')  Camp Gateway - Sandy Hook
#
#                                               park_link  park_latitude  \
# 884   https://www.rei.com/campgrounds/camp/115201894...        34.2944
# 1856  https://www.rei.com/campgrounds/camp/115196800...        34.5431
# 2674                                                NaN            NaN
# 1932  https://www.rei.com/campgrounds/camp/115201894...        34.2944
# 455   https://www.rei.com/campgrounds/camp/115208172...        40.8855
# 3237                                                NaN            NaN
# 757   https://www.rei.com/campgrounds/camp/115194711...        33.6558
# 2791                                                NaN            NaN
# 1099  https://www.rei.com/campgrounds/camp/115201859...        34.2296
# 664   https://www.rei.com/campgrounds/camp/115197386...        40.4492
#
#       park_longitude                                     attracion_link
# 884        -118.2407  https://www.tripadvisor.com.br/Attractions-g60...
# 1856       -119.8203  https://www.tripadvisor.com.br/Attractions-g60...
# 2674             NaN  https://www.tripadvisor.com.br/Attractions-g32...
# 1932       -118.2407  https://www.tripadvisor.com.br/Attractions-g42...
# 455         -73.5012  https://www.tripadvisor.com.br/Attractions-g60...
# 3237             NaN  https://www.tripadvisor.com.br/Attractions-g60...
# 757        -117.4603  https://www.tripadvisor.com.br/Attractions-g60...
# 2791             NaN  https://www.tripadvisor.com.br/Attractions-g32...
# 1099       -118.1769  https://www.tripadvisor.com.br/Attractions-g60...
# 664         -73.9961  https://www.tripadvisor.com.br/Attractions-g60...

# %%
## Saving the new DataFrame to a CSV file

new_df.to_csv('new_df.csv')

# %%
new_df = pd.read_csv('new_df.csv')

# %%
## Removing parenthesis from coordinates column
new_df['event_coordinates'] = new_df['event_coordinates'].str.strip('(')
new_df['event_coordinates'] = new_df['event_coordinates'].str.strip(')')
new_df.head(1)
# Out:
#    Unnamed: 0                                         event_name      date  \
# 0           0  The Breakfast Club - New Years Day 2020 with J...  1/1/2020
#
#                                          description  \
# 0  We're back! What started at ETG has been carry...
#
#                                              line_up  \
# 0  John Tejada, Tara Brooks, Jay Tripwire, Mary D...
#
#                                        event_link            place     city  \
# 0  https://www.residentadvisor.net/events/1358885  The Monkey Loft  seattle
#
#             event_coordinates                  park_name  \
# 0  '47.577129', '-122.334469'  Camp Gateway- Brooklyn Ny
#
#                                            park_link  park_latitude  \
# 0  https://www.rei.com/campgrounds/camp/115196040...        40.5958
#
#    park_longitude                                     attracion_link
# 0        -73.8858  https://www.tripadvisor.com.br/Attractions-g60...

# %%
## Spliting the 'event_coordinates' into two new columns 'event_latitude' and 'event_longitude'
new_df[['event_latitude', 'event_longitude']] = new_df.event_coordinates.str.split(',', expand=True)

# %%
## Deleting the 'event_coordinates' column
del new_df['event_coordinates']

# %%
del new_df['Unnamed: 0']

# %%
new_df.head(1)
# Out:
#                                           event_name      date  \
# 0  The Breakfast Club - New Years Day 2020 with J...  1/1/2020
#
#                                          description  \
# 0  We're back! What started at ETG has been carry...
#
#                                              line_up  \
# 0  John Tejada, Tara Brooks, Jay Tripwire, Mary D...
#
#                                        event_link            place     city  \
# 0  https://www.residentadvisor.net/events/1358885  The Monkey Loft  seattle
#
#                    park_name  \
# 0  Camp Gateway- Brooklyn Ny
#
#                                            park_link  park_latitude  \
# 0  https://www.rei.com/campgrounds/camp/115196040...        40.5958
#
#    park_longitude                                     attracion_link  \
# 0        -73.8858  https://www.tripadvisor.com.br/Attractions-g60...
#
#   event_latitude event_longitude
# 0    '47.577129'   '-122.334469'
