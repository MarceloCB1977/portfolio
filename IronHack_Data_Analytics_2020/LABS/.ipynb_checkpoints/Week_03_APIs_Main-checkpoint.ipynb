# %% [markdown]
# # API Scavenger Game
#
# ## Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp.

# %%
# import libraries here
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import re

# %% [markdown]
# Assuming the main lab repo is ironhack-datalabs/mad-oct-2018, you will:
#
# #### 1. Obtain the full list of forks created from the main lab repo via Github API.

# %% [markdown]
# To list forks, we can use the GET method. As explained in the GitHub API documentation, we need to make the request to: GET /repos/:owner/:repo/forks.

# %%
# your code here
git_token = 
user_name = 


response = requests.get("https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/forks", auth=(user_name, git_token)).json()
response
# Out:
# [{'id': 220066216,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMjAwNjYyMTY=',
#   'name': 'mad-oct-2018',
#   'full_name': 'ToniPons97/mad-oct-2018',
#   'private': False,
#   'owner': {'login': 'ToniPons97',
#    'id': 45130294,
#    'node_id': 'MDQ6VXNlcjQ1MTMwMjk0',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/45130294?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ToniPons97',
#    'html_url': 'https://github.com/ToniPons97',
#    'followers_url': 'https://api.github.com/users/ToniPons97/followers',
#    'following_url': 'https://api.github.com/users/ToniPons97/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ToniPons97/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ToniPons97/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ToniPons97/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ToniPons97/orgs',
# ...

# %% [markdown]
# #### 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
## Accessing via Languages URL
url = response[1]["languages_url"]
bsp = BeautifulSoup(requests.get(url).content)
bsp
# Out:
# <html><head></head><body>{"Jupyter Notebook":1134241,"HTML":498316,"Python":8691}</body></html>

# %%
test = bsp.text
test
#re.sub(r'{}:\d+', '', test)
re.findall(r'[A-Z a-z]+', test)
# Out:
# ['Jupyter Notebook', 'HTML', 'Python']

# %%
t = [fork['languages_url']for fork in response]
result=[]
for url in t:
    b = BeautifulSoup(requests.get(url).content)
    c = b.text
    d = re.findall(r'[A-Z a-z]+', c)
print(d)
# Out:
# ['Jupyter Notebook', 'HTML', 'Python']

# %%
## Accessing via language
forks = set([fork["language"] for fork in response])
forks
# Out:
# {'HTML', 'Jupyter Notebook', None}

# %% [markdown]
# ## Challenge 2: Count Commits
# Count how many commits were made in the month of january of 2019.
#
# Hints:
# - https://developer.github.com/v3/repos/commits/#list-commits-on-a-repository
#
# - GET /repos/:owner/:repo/commits
#
# #### 1. Obtain all the commits made in January 2019 via API, which is a JSON array that contains multiple commit objects.

# %%
# your code here
git_token = 
user_name = 
url = "https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/commits"
commit = requests.get(url, auth=(user_name, git_token)).json()
commit
# Out:
# [{'sha': '1638e5506e6947b77bfe78761d345476ae80d017',
#   'node_id': 'MDY6Q29tbWl0MTUzNzIwODA0OjE2MzhlNTUwNmU2OTQ3Yjc3YmZlNzg3NjFkMzQ1NDc2YWU4MGQwMTc=',
#   'commit': {'author': {'name': 'Marc Pomar',
#     'email': 'marc@faable.com',
#     'date': '2019-08-19T11:11:36Z'},
#    'committer': {'name': 'Marc Pomar',
#     'email': 'marc@faable.com',
#     'date': '2019-08-19T11:11:36Z'},
#    'message': 'Cambiar los autores',
#    'tree': {'sha': '51812285dc70ac37103735ee7ed672befc582b5f',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/trees/51812285dc70ac37103735ee7ed672befc582b5f'},
#    'url': 'https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/commits/1638e5506e6947b77bfe78761d345476ae80d017',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %% [markdown]
# #### 2. Count how many commit objects are contained in the array.

# %%
# your code here
len(commit)
# Out:
# 30

# %%
## Another way 
git_token = 
user_name = 
url = 'https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/commits'+'?since=2018-12-31T23:59:59Z&until=2019-02-01T00:00:00Z'
commit2 = requests.get(url, auth=(user_name, git_token)).json()

# %%
commit2
# Out:
# [{'sha': '41e09d4fbf64bacb2fdfe7d90cdd0cd71bd24310',
#   'node_id': 'MDY6Q29tbWl0MTUzNzIwODA0OjQxZTA5ZDRmYmY2NGJhY2IyZmRmZTdkOTBjZGQwY2Q3MWJkMjQzMTA=',
#   'commit': {'author': {'name': 'Tony Ojeda',
#     'email': 'tojeda@districtdatalabs.com',
#     'date': '2019-01-18T18:28:33Z'},
#    'committer': {'name': 'Tony Ojeda',
#     'email': 'tojeda@districtdatalabs.com',
#     'date': '2019-01-18T18:28:33Z'},
#    'message': 'Parallelization lab',
#    'tree': {'sha': '74662fcb1b617f9be19739c27c841f9d04532399',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/trees/74662fcb1b617f9be19739c27c841f9d04532399'},
#    'url': 'https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/commits/41e09d4fbf64bacb2fdfe7d90cdd0cd71bd24310',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %%
len(commit2)
# Out:
# 30

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# #### 1. Find the secret files.

# %%
# your code here
git_token = 
user_name = 
url = "https://api.github.com/repos/ironhack-datalabs/scavenger/contents"
sca2 = requests.get(url, auth=(user_name, git_token))
sca2
# Out:
# <Response [200]>

# %%
git_token = 
user_name = 
url = 'https://api.github.com/search/code?q=extension:scavengerhunt+repo:ironhack-datalabs/scavenger'
scavenger = requests.get(url, auth=(user_name, git_token)).json()

# %%
scavenger
# Out:
# {'total_count': 24,
#  'incomplete_results': False,
#  'items': [{'name': '.0006.scavengerhunt',
#    'path': '15024/.0006.scavengerhunt',
#    'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#    'url': 'https://api.github.com/repositories/162375181/contents/15024/.0006.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#    'git_url': 'https://api.github.com/repositories/162375181/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/15024/.0006.scavengerhunt',
#    'repository': {'id': 162375181,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#     'name': 'scavenger',
#     'full_name': 'ironhack-datalabs/scavenger',
#     'private': False,
#     'owner': {'login': 'ironhack-datalabs',
#      'id': 44225188,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/44225188?v=4',
# ...

# %% [markdown]
# #### 2.  Sort the filenames ascendingly.

# %%
# your code here
order_scavenger = sorted([x['name'] for x in scavenger['items']])
order_scavenger
# Out:
# ['.0001.scavengerhunt',
#  '.0002.scavengerhunt',
#  '.0003.scavengerhunt',
#  '.0004.scavengerhunt',
#  '.0005.scavengerhunt',
#  '.0006.scavengerhunt',
#  '.0007.scavengerhunt',
#  '.0008.scavengerhunt',
#  '.0009.scavengerhunt',
#  '.0010.scavengerhunt',
#  '.0011.scavengerhunt',
#  '.0012.scavengerhunt',
#  '.0013.scavengerhunt',
#  '.0014.scavengerhunt',
#  '.0015.scavengerhunt',
#  '.0016.scavengerhunt',
#  '.0017.scavengerhunt',
#  '.0018.scavengerhunt',
#  '.0019.scavengerhunt',
#  '.0020.scavengerhunt',
#  '.0021.scavengerhunt',
#  '.0022.scavengerhunt',
#  '.0023.scavengerhunt',
#  '.0024.scavengerhunt']

# %% [markdown]
# #### 3. Read the content of each secret files into an array of strings.
# Since the response is encoded, you will need to send the following information in the header of your request:
# ````python
# headers = {'Accept': 'application/vnd.github.v3.raw'}
# ````

# %%
# your code here
scan_result = [[]]*24
for item in scavenger['items']:
    x = requests.get(item['url'], headers = {'Accept': 'application/vnd.github.v3.raw'}).text
    index = order_scavenger.index(item['name'])
    scan_result[index] = x

# %% [markdown]
# #### 4. Concatenate the strings in the array separating each two with a whitespace.

# %%
# your code here
scan_result = ''.join(scan_result)

# %% [markdown]
# #### 5. Print out the joke.

# %%
# your code here
print(scan_result)
