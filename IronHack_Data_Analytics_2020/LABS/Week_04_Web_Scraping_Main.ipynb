# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended content.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit the urls below and take a look at their source code through Chrome DevTools. You'll need to identify the html tags, special class names, etc used in the html content you are expected to extract.
#
# **Resources**:
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide)
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are already imported for you. If you prefer to use additional libraries feel free to do it.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'
cont = BeautifulSoup(requests.get(url).content)

# %%
# your code here
cont
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-e41b3811197df7fbb60147e939917617.css" integrity="sha512-5Bs4ERl99/u2AUfpOZF2F0cdfNby7+Vd9teUshXUBPo5CjwECR7IAEf+weI/eCk5tF7K1h3O8hd8k0+P/HePeg==" media="all" rel="stylesheet"/>
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
# your code here
h1_find = cont.find_all('h1', attrs={'class' : 'h3 lh-condensed'})
names = [x.text.strip() for x in h1_find]
print(f"The names of the trending developers are")
names
# Out:
# The names of the trending developers are
# ['Lipis',
#  'David Peter',
#  'Vítor Galvão',
#  'Greg Bergé',
#  'Larry Davis',
#  'Milos Kozak',
#  'Franck Nijhof',
#  'Paulus Schoutsen',
#  'Jethro Kuan',
#  'Arvid Norberg',
#  'Henrik Rydgård',
#  'maiyang',
#  'Samuel Colvin',
#  'Jorge Bucaran',
#  'Irfan Maulana',
#  'Mimi',
#  'Bartlomiej Plotka',
#  'Michiel Borkent',
#  'Kamran Ahmed',
#  'Oliver Kopp',
#  'Ayke',
#  'Wim',
#  'Sebastián Ramírez',
#  'Luan Nico',
#  'Ahmad Awais ⚡️']

# %% [markdown]
# #### Display the trending Python repositories in GitHub.
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'
top_py = BeautifulSoup(requests.get(url).content)

# %%
# your code here
pytop = top_py.find_all('h1', attrs={'class' : 'h3 lh-condensed'})
top_names = [x.text.strip().replace(' ', '').replace('\n', '').replace('/', ' - ') for x in pytop]
print(f"The trending Python repositories are")
top_names
# Out:
# The trending Python repositories are
# ['datasets - covid-19',
#  'home-assistant - core',
#  'coronasafe - care',
#  'kon9chunkit - GitHub-Chinese-Top-Charts',
#  'google - automl',
#  'tensortrade-org - tensortrade',
#  'J535D165 - CoronaWatchNL',
#  'StevenBlack - hosts',
#  'turicas - covid19-br',
#  'OpenMined - PySyft',
#  'python-telegram-bot - python-telegram-bot',
#  'hexway - r00kie-kr00kie',
#  'crinny - b0mb3r',
#  'ycm-core - YouCompleteMe',
#  'Kr1s77 - awesome-python-login-model',
#  'sqlmapproject - sqlmap',
#  'KalleHallden - BookOmatic',
#  'apachecn - AiLearning',
#  'Unity-Technologies - ml-agents',
#  'xuannianz - EfficientDet',
#  'COVID19Tracking - covid-tracking-data',
#  'timgrossmann - InstaPy',
#  'geekcomputers - Python',
#  'deezer - spleeter',
#  'scikit-learn - scikit-learn']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'
table = BeautifulSoup(requests.get(url).content)

# %%
tdd = table.find_all('a', attrs={'class' : 'image'})[0]['href']

# %%
tdd
# Out:
# '/wiki/File:Walt_Disney_1946.JPG'

# %%
links = ['https://en.wikipedia.org' + x['href'] for x in table.find_all('a', attrs={'class' : 'image'})]

# %%
print(f"The links for all the images are listed below")
links
# Out:
# The links for all the images are listed below
# ['https://en.wikipedia.org/wiki/File:Walt_Disney_1946.JPG',
#  'https://en.wikipedia.org/wiki/File:Walt_Disney_1942_signature.svg',
#  'https://en.wikipedia.org/wiki/File:Walt_Disney_envelope_ca._1921.jpg',
#  'https://en.wikipedia.org/wiki/File:Trolley_Troubles_poster.jpg',
#  'https://en.wikipedia.org/wiki/File:Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg',
#  'https://en.wikipedia.org/wiki/File:Steamboat-willie.jpg',
#  'https://en.wikipedia.org/wiki/File:Walt_Disney_1935.jpg',
#  'https://en.wikipedia.org/wiki/File:Walt_Disney_Snow_white_1937_trailer_screenshot_(13).jpg',
#  'https://en.wikipedia.org/wiki/File:Disney_drawing_goofy.jpg',
#  'https://en.wikipedia.org/wiki/File:DisneySchiphol1951.jpg',
#  'https://en.wikipedia.org/wiki/File:WaltDisneyplansDisneylandDec1954.jpg',
#  'https://en.wikipedia.org/wiki/File:Walt_disney_portrait_right.jpg',
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page.

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'
py_page = BeautifulSoup(requests.get(url).content)

# %%
# your code here
py_page.find_all('link')
#py_links = [x['href'] for x in py_page.find_all('a')]
# Out:
# [<link href="/w/load.php?lang=en&amp;modules=ext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.toc.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>,
#  <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>,
#  <link href="/w/index.php?title=Python&amp;action=edit" rel="alternate" title="Edit this page" type="application/x-wiki"/>,
#  <link href="/w/index.php?title=Python&amp;action=edit" rel="edit" title="Edit this page"/>,
#  <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>,
#  <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>,
#  <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>,
#  <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>,
# ...

# %% [markdown]
# #### Find the number of titles that have changed in the United States Code since its last release point.

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'
titles = BeautifulSoup(requests.get(url).content)

# %%
title_change = [x.text.strip() for x in titles.find_all('div', attrs={'class':'usctitlechanged'})]

# %%
# your code here
print(f"Number os titles changed is: {len(title_change)}")
title_change
# Out:
# Number os titles changed is: 32
# ['Title 1 - General Provisions ٭',
#  'Title 2 - The Congress',
#  'Title 5 - Government Organization and Employees ٭',
#  'Title 6 - Domestic Security',
#  'Title 7 - Agriculture',
#  'Title 8 - Aliens and Nationality',
#  'Title 12 - Banks and Banking',
#  'Title 15 - Commerce and Trade',
#  'Title 16 - Conservation',
#  'Title 17 - Copyrights ٭',
#  'Title 18 - Crimes and Criminal Procedure ٭',
#  'Title 20 - Education',
#  'Title 21 - Food and Drugs',
#  'Title 22 - Foreign Relations and Intercourse',
#  'Title 23 - Highways ٭',
#  'Title 26 - Internal Revenue Code',
#  'Title 29 - Labor',
#  'Title 30 - Mineral Lands and Mining',
#  'Title 31 - Money and Finance ٭',
#  'Title 36 - Patriotic and National Observances, Ceremonies, and Organizations ٭',
#  "Title 38 - Veterans' Benefits ٭",
#  'Title 41 - Public Contracts ٭',
#  'Title 42 - The Public Health and Welfare',
#  'Title 43 - Public Lands',
# ...

# %% [markdown]
# #### Find a Python list with the top ten FBI's Most Wanted names.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'
fbi = BeautifulSoup(requests.get(url).content)

# %%
# your code here
#fbi.find_all('h3')[0].text.strip()
fbi_mostwanted = [x.text.strip() for x in fbi.find_all('h3')]
print(f"FBI Most Wanted list")
fbi_mostwanted
# Out:
# FBI Most Wanted list
# ['SANTIAGO VILLALBA MEDEROS',
#  'RAFAEL CARO-QUINTERO',
#  'ROBERT WILLIAM FISHER',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ALEJANDRO ROSALES CASTILLO',
#  'ARNOLDO JIMENEZ',
#  'YASER ABDEL SAID',
#  'JASON DEREK BROWN',
#  'ALEXIS FLORES',
#  'EUGENE PALMER']

# %% [markdown]
# ####  Display the 20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'
earthq = BeautifulSoup(requests.get(url).content)

# %%
# your code here
earthq.find_all('table')
# Out:
# [<table cellpadding="0" cellspacing="0" class="ban0"><tr><td class="ban1" onclick="window.location.href='https://www.emsc-csem.org';" onmouseover="this.style.cursor='pointer';">
#  <img alt="logo - home" src="https://static2.emsc.eu/Css/img/logo.png" style="width:150px;height:81px;"/></td>
#  <td class="ban2 ban022" onclick="window.location.href='https://www.emsc-csem.org';" onmouseover="this.style.cursor='pointer';">
#  <div style="border:0; position:relative; float:right; width:110px; height:80px; margin-top:-5px; margin-right:25px; ">
#  <div id="androidstore" style="border:0; position:relative; float:left; width:110px; height:35px;"></div>
#  <div id="iosstore" style="border:0; position:relative; float:left; width:110px; height:35px; margin-top:8px;"></div>
#  </div>
#  <script type="text/javascript">set_server_date(2020,3,24,11,6,46)</script>
#  <div id="ejs_server_heure">Current time: 2020-03-24 11:06:46 UTC</div>
#  </td>
# ...

# %%
headers = [header.text.strip() for header in earthq.find_all('th')]
headers
# Out:
# ['CitizenResponse',
#  'Date & Time UTC',
#  'Latitude degrees',
#  'Longitude degrees',
#  'Depth km',
#  'Mag  [+]',
#  'Region name  [+]',
#  'Last update [-]']

# %%
date_time = earthq.find_all('td', attrs={'class': 'tabev6'})

# %%
dates = [x.find('a').text.split() for x in date_time]
dates[0]
date = [x[0] for x in dates]
time = [x[1] for x in dates]
lat_long_x = [x.text.replace('\xa0','') for x in earthq.find_all('td', attrs={'class': 'tabev1'})]
lat_long = np.reshape(lat_long_x, (50, 2))
lat = [x[0] for x in lat_long]
long = [x[1] for x in lat_long]
reg = [x.text.replace('\xa0', '') for x in earthq.find_all('td', attrs={'class':'tb_region'})]
d = {'Date':date, 'Time':time, 'Latitude':lat, 'Longitude':long, 'Region Name':reg}
earth_q = pd.DataFrame(d)
earth_q[:21]
# Out:
#           Date        Time Latitude Longitude                     Region Name
# 0   2020-03-24  10:57:03.6    19.18    155.47        ISLAND OF HAWAII, HAWAII
# 1   2020-03-24  10:44:04.9    38.47     39.22                  EASTERN TURKEY
# 2   2020-03-24  10:35:59.0     7.89    123.05                       BANDA SEA
# 3   2020-03-24  10:34:15.0     1.85    126.31                     MOLUCCA SEA
# 4   2020-03-24  10:31:27.0    15.86    119.02              LUZON, PHILIPPINES
# 5   2020-03-24  10:20:55.0    30.62     71.57                 COQUIMBO, CHILE
# 6   2020-03-24  10:11:48.3    17.94     66.98              PUERTO RICO REGION
# 7   2020-03-24  09:53:46.0     1.11     78.77  COLOMBIA-ECUADOR BORDER REGION
# 8   2020-03-24  09:47:45.0    33.60    117.21             SOUTHERN CALIFORNIA
# 9   2020-03-24  09:42:18.4    69.55    144.19                 NORTHERN ALASKA
# 10  2020-03-24  09:40:08.4    56.62    149.24                  GULF OF ALASKA
# ...

# %% [markdown]
# #### Count the number of tweets by a given Twitter account.
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Number of followers of a given twitter account
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the followers for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'
wiki_lang = BeautifulSoup(requests.get(url).content)

# %%
# your code here
wiki = wiki_lang.find_all('div', attrs={'class':'central-featured-lang'})
wik_text = [x.find('strong').text.strip() for x in wiki_lang.find_all('div', attrs={'class':'central-featured-lang'})]
wik_art = [x.find('bdi').text.replace('\xa0', '') for x in wiki_lang.find_all('div', attrs={'class':'central-featured-lang'})]
wiki_list = list(zip(wik_text, wik_art))
wiki_list
# Out:
# [('English', '6029000+'),
#  ('Español', '1581000+'),
#  ('日本語', '1193000+'),
#  ('Deutsch', '2406000+'),
#  ('Русский', '1602000+'),
#  ('Français', '2187000+'),
#  ('Italiano', '1588000+'),
#  ('中文', '1101000+'),
#  ('Português', '1023000+'),
#  ('Polski', '1388000+')]

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk.

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'
uk_gov = BeautifulSoup(requests.get(url).content)

# %%
# your code here
uk_data = [x.text for x in uk_gov.find_all('h2')]
uk_data
# Out:
# ['Business and economy',
#  'Crime and justice',
#  'Defence',
#  'Education',
#  'Environment',
#  'Government',
#  'Government spending',
#  'Health',
#  'Mapping',
#  'Society',
#  'Towns and cities',
#  'Transport']

# %% [markdown]
# #### Display the top 10 languages by number of native speakers stored in a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
# your code here875
tables = pd.read_html(url)
df = tables[2]
header = df.iloc[0]
df = df[1:]
df.columns = header
df.iloc[:10,:]
# Out:
# 0  Rank                  Language Nativespeakersin millions2007 (2010)  \
# 1     1  Mandarin (entire branch)                            935 (955)
# 2     2                   Spanish                            390 (405)
# 3     3                   English                            365 (360)
# 4     4                  Hindi[a]                            295 (310)
# 5     5                    Arabic                            280 (295)
# 6     6                Portuguese                            205 (215)
# 7     7                   Bengali                            200 (205)
# 8     8                   Russian                            160 (155)
# 9     9                  Japanese                            125 (125)
# 10   10                   Punjabi                             95 (100)
#
# 0  Percentageof worldpopulation(2007)
# 1                               14.1%
# 2                               5.85%
# 3                               5.52%
# ...

# %% [markdown]
# ## Bonus
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Display IMDB's top 250 data (movie name, initial release, director name and stars) as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'
movie = BeautifulSoup(requests.get(url).content)

# %%
# your code here
title = [x.text.replace(' ', '').replace('\n', '').strip().split('.') for x in movie.find_all('td', attrs={'class':'titleColumn'})]
title_col = [x[1] for x in title]
rank_col = [x[0] for x in title]
title2 = [x for x in movie.find_all('td', attrs={'class':'titleColumn'})]

# %%
title_x = movie.find('td', attrs={'class':'titleColumn'})
title_x.find_all('a')
# Out:
# [<a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">Um Sonho de Liberdade</a>]

# %% [markdown]
# #### Display the movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = input('Enter the city: ')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code here

# %% [markdown]
# #### Find the book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
# your code here
